# %%
import pandas as pd
import os
import statistics as stat

# %%
c = 0
all_files = []
for root, dirs, files in os.walk(".", topdown = False):
    for name in files:
        if name[0:6] == 'mental':
            #print(name)
            all_files.append(name)
            c += 1
print(f'total cases: {c}')
all_files = sorted(all_files)
print(all_files, '\n', len(all_files))
# Out:
# total cases: 85
# ['mentalrotation75.2020-12-16-0705.data.74f81e30-3d39-4e56-843d-460dd8860b7a.txt', 'mentalrotation75.2020-12-16-0743.data.3a894f49-ad82-4f90-bcd4-fa9122d117f6.txt', 'mentalrotation75.2020-12-16-0744.data.3b0c633c-f71c-4f7c-bcc6-adc5cb532496.txt', 'mentalrotation75.2020-12-16-0746.data.54b31372-1c7e-4526-9b41-0eec96e51745.txt', 'mentalrotation75.2020-12-16-0746.data.5d2b24d2-c618-4257-9f42-9ac7268f2f0a.txt', 'mentalrotation75.2020-12-16-0747.data.fe42c168-cc6c-407d-a505-eda02c57688b.txt', 'mentalrotation75.2020-12-16-0751.data.b9b3d7f3-845f-44b7-93c4-f42a9fa85a6e.txt', 'mentalrotation75.2020-12-16-0836.data.6c18ff7a-a808-4b46-9c4a-c877f54556be.txt', 'mentalrotation75.2020-12-16-1006.data.30b7962d-a4f6-4dea-afc5-9a8886d38fbe.txt', 'mentalrotation75.2020-12-16-1136.data.22ed1968-05c1-4734-88a3-97c939e7cb45.txt', 'mentalrotation75.2020-12-16-1352.data.6b6e76a1-b56d-49c3-a62e-49ce5feae6d1.txt', 'mentalrotation75.2020-12-16-1415.data.cb795f1d-d0cc-40a4-89bb-0b6ae596c19e.txt', 'mentalrotation75.2020-12-16-1504.data.e0c770cd-80ff-4e2d-8a60-d0b231f6a25c.txt', 'mentalrotation75.2020-12-16-1519.data.6022ec22-a1fe-4ed7-ae58-994aadefe209.txt', 'mentalrotation75.2020-12-17-0924.data.07618df7-a8ab-4925-b4a2-2dc703bfc5b3.txt', 'mentalrotation75.2020-12-18-0650.data.00775079-b61c-49aa-849a-e46e8833878f.txt', 'mentalrotation75.2020-12-18-1351.data.a860bef1-7355-4697-9ffd-7c1b3f50e4b1.txt', 'mentalrotation75.2020-12-18-1507.data.2a27edcb-6ea8-4b1e-bfb6-0e9dcfcb7045.txt', 'mentalrotation75.2020-12-18-1720.data.e5d8f8a5-9149-448e-ac2f-e0f6d6c9ec14.txt', 'mentalrotation75.2020-12-18-1849.data.8145ee30-25be-4a32-af91-b5eefede81c7.txt', 'mentalrotation75.2020-12-19-0624.data.1e03890f-6c35-4a80-bf8b-007ee47d3ba9.txt', 'mentalrotation75.2020-12-19-0830.data.8c9aa05c-325b-48aa-b952-bca63957d0a2.txt', 'mentalrotation75.2020-12-19-0953.data.37354e44-bc46-456f-aeb7-dfcd440030dd.txt', 'mentalrotation75.2020-12-20-0509.data.ca169b99-3915-41d2-9a6e-d3cfcc9a5591.txt', 'mentalrotation75.2020-12-20-0651.data.7fd141d7-c13d-4a45-81da-53b622ea0a9f.txt', 'mentalrotation75.2020-12-20-0654.data.6726ec83-c963-4b30-aa15-7e4c6f79ce02.txt', 'mentalrotation75.2020-12-20-0835.data.2aef4e8f-2b3c-4383-bfd6-9b0bd94dfbb8.txt', 'mentalrotation75.2020-12-20-1509.data.a9980f93-6050-4334-86f7-c2e9b7a89de6.txt', 'mentalrotation75.2020-12-20-1511.data.35d7bb99-707d-403b-841a-4910898ee76e.txt', 'mentalrotation75.2020-12-21-0807.data.549f087f-4705-4d4a-bc66-46ee7163d9ef.txt', 'mentalrotation75.2020-12-21-1109.data.71aaa2a1-2275-4d3d-9718-829e4f02f76e.txt', 'mentalrotation75.2020-12-21-1639.data.895df812-f78b-4aae-92c6-323f27fb9353.txt', 'mentalrotation75.2020-12-21-1744.data.119cf1ae-b9f3-4618-a8b1-b14f6bfa3962.txt', 'mentalrotation75.2020-12-22-1017.data.5490b40a-3f7b-401c-8ffe-e30129eb960a.txt', 'mentalrotation75.2020-12-22-1031.data.5a7ac882-07ae-4e2f-8786-67bc8e260eaf.txt', 'mentalrotation75.2020-12-22-1315.data.c733a162-efaf-42a7-bd58-bc9c10ec0955.txt', 'mentalrotation75.2020-12-22-1339.data.cbfcaeae-44af-4706-befd-4fed05fb4529.txt', 'mentalrotation75.2020-12-22-1423.data.fefec30f-1b10-47bb-a014-52c7c4fc60d0.txt', 'mentalrotation75.2020-12-22-1522.data.8e07227f-f1da-4ea4-abaa-665d6e420f65.txt', 'mentalrotation75.2020-12-22-1529.data.246a5881-b206-4184-9d35-a9a110328585.txt', 'mentalrotation75.2020-12-22-1637.data.b287a47d-8f9d-4c0c-8a46-5b304f0111ab.txt', 'mentalrotation75.2020-12-22-1803.data.a3d3f7c9-bfef-4951-9fc0-9b14189dcf0b.txt', 'mentalrotation75.2020-12-22-1837.data.97753296-5140-4945-a83b-3687f54d7891.txt', 'mentalrotation75.2020-12-22-2006.data.46d57fa4-821d-4983-9d05-732ad00357e4.txt', 'mentalrotation75.2020-12-23-0231.data.5c0b5409-7b54-4c27-9a2f-8ad6d0d775a5.txt', 'mentalrotation75.2020-12-23-0326.data.3cd2b752-b14d-4c5a-a573-12cfdd66e07f.txt', 'mentalrotation75.2020-12-23-0331.data.ee6563d9-619d-4fdb-8053-5da9f5287d84.txt', 'mentalrotation75.2020-12-23-0603.data.cdba2457-130d-48ab-91bd-af17b60ef9a7.txt', 'mentalrotation75.2020-12-23-0610.data.857a0847-e24e-4259-b14f- ...
#  85

# %%
data = pd.read_csv(all_files[0], header=None)
print(data)
# Out:
#                            0
# 0     training 80 2 D 1 3664
# 1     training 40 2 D 2 2129
# 2      training 0 1 P 1 1354
# 3    training 160 2 P 2 2661
# 4     training 40 2 P 2 3621
# ..                       ...
# 200       test2 0 2 P 2 1405
# 201     test2 120 1 D 1 1472
# 202      test2 80 1 P 1 2931
# 203     test2 120 2 P 1 1056
# 204      test2 40 2 D 2 2534
#
# [205 rows x 1 columns]

# %%
n = []
d0d = []
d0p = []
d40d = []
d40p = []
d80d = []
d80p = []
d120d = []
d120p = []
d160d = []
d160p = []

for i in range(len(all_files)):
    data = pd.read_csv(all_files[i], sep=' ', header=None)
    data.columns = ["test","degree","trial","type","correct","time"]
    data = data.drop([0,1,2,3,4])
    
    data = data[data.correct != 3]
    #print(data)
    
    deg0 = data[data.degree == 0]
    deg40 = data[data.degree == 40]
    deg80 = data[data.degree == 80]
    deg120 = data[data.degree == 120]
    deg160 = data[data.degree == 160]
    
    deg0d = deg0[deg0.type == 'D']
    deg0p = deg0[deg0.type == 'P']
    
    deg40d = deg40[deg40.type == 'D']
    deg40p = deg40[deg40.type == 'P']
    
    deg80d = deg80[deg80.type == 'D']
    deg80p = deg80[deg80.type == 'P']
    
    deg120d = deg120[deg120.type == 'D']
    deg120p = deg120[deg120.type == 'P']
    
    deg160d = deg160[deg160.type == 'D']
    deg160p = deg160[deg160.type == 'P']
    
    name = all_files[i]
    n.append(name)
    
    a = stat.mean(deg0d['time'])
    b = stat.mean(deg0p['time'])
    d0d.append(a)
    d0p.append(b)
    
    c = stat.mean(deg40d['time'])
    d = stat.mean(deg40p['time'])
    d40d.append(c)
    d40p.append(d)
    
    e = stat.mean(deg80d['time'])
    f = stat.mean(deg80p['time'])
    d80d.append(e)
    d80p.append(f)
    
    g = stat.mean(deg120d['time'])
    h = stat.mean(deg120p['time'])
    d120d.append(g)
    d120p.append(h)
    
    i = stat.mean(deg160d['time'])
    j = stat.mean(deg160p['time'])
    d160d.append(i)
    d160p.append(j)

# %%
dic = {
    "name": n, 
    "degree0D": d0d,
    "degree0P": d0p,
    "degree40D": d40d,
    "degree40P": d40p,
    "degree80D": d80d,
    "degree80P": d80p,
    "degree120D": d120d,
    "degree120P": d120p,
    "degree160D": d160d,
    "degree160P": d160p}

df = pd.DataFrame(dic)
df.to_csv(os.getcwd()+'/mean_data.csv')
df
# Out:
#                                                  name     degree0D  \
# 0   mentalrotation75.2020-12-16-0705.data.74f81e30...  1498.050000
# 1   mentalrotation75.2020-12-16-0743.data.3a894f49...  1962.285714
# 2   mentalrotation75.2020-12-16-0744.data.3b0c633c...  4105.578947
# 3   mentalrotation75.2020-12-16-0746.data.54b31372...  2955.761905
# 4   mentalrotation75.2020-12-16-0746.data.5d2b24d2...  2698.550000
# ..                                                ...          ...
# 80  mentalrotation75.2020-12-31-0323.data.55166c2b...  2105.421053
# 81  mentalrotation75.2021-01-05-0750.data.b914412a...  2261.500000
# 82  mentalrotation75.2021-01-05-1038.data.697667a1...  3006.150000
# 83  mentalrotation75.2021-01-05-1720.data.f6801838...  1519.900000
# 84  mentalrotation75.2021-01-06-0404.data.82493da9...  1832.350000
#
#        degree0P    degree40D    degree40P    degree80D    degree80P  \
# 0   2292.736842  2661.947368  2584.470588  2791.944444  2992.000000
# 1   1989.100000  2590.000000  3007.950000  3727.450000  3078.947368
# 2   2313.450000  3650.857143  3614.250000  5309.300000  4168.100000
# 3   2939.400000  6195.368421  3704.950000  7726.000000  6890.095238
# 4   1805.900000  2845.727273  4262.809524  5951.300000  5004.000000
# ..          ...          ...          ...          ...          ...
# 80  2636.777778  5633.789474  4327.789474  5718.400000  4446.750000
# 81  1976.631579  3252.666667  2491.631579  3828.272727  3696.650000
# 82  1596.050000  4951.857143  3724.571429  6792.850000  4806.428571
# 83   751.500000  1655.600000  2067.818182  1520.000000  2089.950000
# 84  2458.900000  3682.650000  3278.666667  4924.700000  5490.750000
#
#      degree120D   degree120P   degree160D   degree160P
# 0   2513.250000  1898.285714  2375.300000  2353.684211
# 1   3111.727273  2955.944444  3012.250000  3255.100000
# 2   6272.631579  5161.157895  4310.190476  4974.400000
# 3   5791.666667  6144.368421  7347.368421  6652.388889
# 4   6652.333333  6600.500000  6861.105263  5669.277778
# ..          ...          ...          ...          ...
# 80  5796.950000  5748.368421  4261.863636  5250.294118
# 81  3801.789474  4188.250000  3162.400000  3944.350000
# 82  6307.263158  4211.450000  5201.000000  5589.263158
# 83   879.050000  1444.050000  2173.800000  2728.650000
# 84  6047.950000  5923.500000  3792.736842  6663.736842
#
# [85 rows x 11 columns]

# %%
df84 = df.drop(66)
df84.to_csv(os.getcwd()+'/mean_data84.csv')
df84
# Out:
#                                                  name     degree0D  \
# 0   mentalrotation75.2020-12-16-0705.data.74f81e30...  1498.050000
# 1   mentalrotation75.2020-12-16-0743.data.3a894f49...  1962.285714
# 2   mentalrotation75.2020-12-16-0744.data.3b0c633c...  4105.578947
# 3   mentalrotation75.2020-12-16-0746.data.54b31372...  2955.761905
# 4   mentalrotation75.2020-12-16-0746.data.5d2b24d2...  2698.550000
# ..                                                ...          ...
# 80  mentalrotation75.2020-12-31-0323.data.55166c2b...  2105.421053
# 81  mentalrotation75.2021-01-05-0750.data.b914412a...  2261.500000
# 82  mentalrotation75.2021-01-05-1038.data.697667a1...  3006.150000
# 83  mentalrotation75.2021-01-05-1720.data.f6801838...  1519.900000
# 84  mentalrotation75.2021-01-06-0404.data.82493da9...  1832.350000
#
#        degree0P    degree40D    degree40P    degree80D    degree80P  \
# 0   2292.736842  2661.947368  2584.470588  2791.944444  2992.000000
# 1   1989.100000  2590.000000  3007.950000  3727.450000  3078.947368
# 2   2313.450000  3650.857143  3614.250000  5309.300000  4168.100000
# 3   2939.400000  6195.368421  3704.950000  7726.000000  6890.095238
# 4   1805.900000  2845.727273  4262.809524  5951.300000  5004.000000
# ..          ...          ...          ...          ...          ...
# 80  2636.777778  5633.789474  4327.789474  5718.400000  4446.750000
# 81  1976.631579  3252.666667  2491.631579  3828.272727  3696.650000
# 82  1596.050000  4951.857143  3724.571429  6792.850000  4806.428571
# 83   751.500000  1655.600000  2067.818182  1520.000000  2089.950000
# 84  2458.900000  3682.650000  3278.666667  4924.700000  5490.750000
#
#      degree120D   degree120P   degree160D   degree160P
# 0   2513.250000  1898.285714  2375.300000  2353.684211
# 1   3111.727273  2955.944444  3012.250000  3255.100000
# 2   6272.631579  5161.157895  4310.190476  4974.400000
# 3   5791.666667  6144.368421  7347.368421  6652.388889
# 4   6652.333333  6600.500000  6861.105263  5669.277778
# ..          ...          ...          ...          ...
# 80  5796.950000  5748.368421  4261.863636  5250.294118
# 81  3801.789474  4188.250000  3162.400000  3944.350000
# 82  6307.263158  4211.450000  5201.000000  5589.263158
# 83   879.050000  1444.050000  2173.800000  2728.650000
# 84  6047.950000  5923.500000  3792.736842  6663.736842
#
# [84 rows x 11 columns]
